# %% [markdown]
# ## Graphing Final Results

# %%
rp =[0.33405788811348813, 0.4216908820501087, 0.5148152385310605, 0.6117149067612402, 0.6601075391831598]
ts = [0.20146436334515502, 0.3662052396750944, 0.5342638142089006, 0.5974144834687106, 0.6579338748426954]
cpc = [0.25225946688021966, 0.44640201349959957, 0.5308317126186936, 0.5721313350875186, 0.6230408420089235]
ramdom_weights = [0.21347671891087977, 0.2367006063379476, 0.337375586317355, 0.35041757236014187, 0.46299050451893375]
full_sup = [0.2691911680585745, 0.3659764329024139, 0.46585058917743966, 0.6034778629447431, 0.7143347443084316]

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
xvals = [1, 10, 100, 1000, 2000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, rp, 'b.-', label="RP", markersize=14)
plt.semilogx(xvals, ts, 'yx-', label="TS", markersize=14)
plt.semilogx(xvals, cpc, 'g*-', label="CPC", markersize=14)
plt.semilogx(xvals, ramdom_weights, 'm+-', label="Random", markersize=14)
plt.semilogx(xvals, full_sup, 'r.-', label="Full Super.", markersize=14)

plt.legend()
plt.xlabel("Number of Examples Per Class", fontsize=18)
plt.ylabel("Test Set Accuracy", fontsize=18)
plt.show()

# %% [markdown]
# ## After Adding More Data

# %%
rp =[0.3046380580840919, 0.4250541829215431, 0.5237104464672735, 0.59913307325531, 0.6680537494581708]
ts = [0.28183788469874294, 0.42306025140875597, 0.52925877763329, 0.610836584308626, 0.6691807542262679]
cpc = [0.28097095795405286, 0.42418725617685304, 0.5448634590377113, 0.5814477676636324, 0.6376246207195492]
ramdom_weights = [0.22600780234070222, 0.22678803641092327, 0.329778933680104, 0.31876896402254007, 0.47169484178586907]
full_sup = [0.23935847420892933, 0.30082358040745555, 0.5131339401820546, 0.5954919809276116, 0.7121803207628955]
All3_combined = [0.33246640658864324, 0.4729085392284352, 0.5831816211530125, 0.6476809709579541, 0.7046380580840919]

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
xvals = [1, 10, 100, 1000, 2000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, rp, 'b.-', label="RP", markersize=14)
plt.semilogx(xvals, ts, 'yx-', label="TS", markersize=14)
plt.semilogx(xvals, cpc, 'g*-', label="CPC", markersize=14)
plt.semilogx(xvals, ramdom_weights, 'm+-', label="Random", markersize=14)
plt.semilogx(xvals, full_sup, 'r.-', label="Full Super.", markersize=14)
plt.semilogx(xvals, All3_combined, '*-', label="All 3", markersize=14)


plt.legend()
plt.xlabel("Number of Examples Per Class", fontsize=18)
plt.ylabel("Test Set Accuracy", fontsize=18)
plt.show()
